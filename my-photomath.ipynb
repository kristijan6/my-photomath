# %%
from postifx_calc import Calculator
from data_loader import DataLoader
from model import Model

# %%
calculator = Calculator()

# %%
calculator.calculate("(1+2) + ((15+3)*8)*1000")
# Out:
# 144003.0

# %%
calculator.calculate("1+2+3+4")
# Out:
# 10.0

# %%
calculator.calculate("6+3-1-5")
# Out:
# 3.0

# %%
calculator.calculate("6*(9/(3*3)*6)/6+1")
# Out:
# 7.0

# %%
data_loader = DataLoader()
data_loader.prepare_input("data/operators_7.png")

# %%
model = Model()

# %%
model.apply_model("data/operators_1.png")
# Out:
# Recognized expression: (0*/55
# Couldn't calculate that expression.

# %%
model.apply_model("data/example_2.jpg")
# Out:
# Recognized expression: 6-3/1*5
# Result: -9.0

# %%
model.apply_model("data/example_3.jpg")
# Out:
# Recognized expression: 2/5-0040
# Result: -39.6

# %%
model.apply_model("data/example_4.jpg")
# Out:
# Recognized expression: 2+2
# Result: 4.0

# %%
model.apply_model("data/example_5.jpg")
# Out:
# Recognized expression: 78)/3-5-4(6-2
# Couldn't calculate that expression.

# %%
model.apply_model("data/example_6.jpg")
# Out:
# Recognized expression: *726-3-16*2-400/
# Couldn't calculate that expression.

# %%
model.apply_model("data/example_11.jpg")
# Out:
# Recognized expression: *)*-*)1*66-3*6-/-012
# Couldn't calculate that expression.
